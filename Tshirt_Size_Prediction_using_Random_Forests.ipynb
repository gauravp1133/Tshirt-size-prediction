# %%
# Lets try to predict the Tshirt size using Random Forest ALgorithm.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv('tshirts.csv')
data.sample(10)
# Out:
#     height_cm  weight_kg size
# 93        201         94  XXL
# 55        168         63    M
# 8         171         66    M
# 80        172         67    L
# 14        201         96  XXL
# 53        205        100  XXL
# 19        189         84  XXL
# 61        198         93  XXL
# 87        171         64    M
# 24        174         69    L
